# %% [markdown]
# <a href="https://colab.research.google.com/github/Sourav61/Goeduhub-Assignments/blob/main/Task_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Author: <a href = "https://github.com/Sourav61">Sourav Pahwa</a>
# <br>ID: GO_STP_13420

# %%
#@title <b>Discuss the concept of One-Hot-Encoding, Multicollinearity and the Dummy Variable Trap.</b>  

print("""1. One Hot Encoding 

  * It is one of the most popular and widely used algorithms to convert the categorical data into numerical data.

  * OneHotEncoder(OHE) can be used for both nominal and ordinal data imported from sklearn.preprocessing.

  * It can be easily performed using Label Encoder and One Hot Encoder imported from sklearn.preprocessing. 

2. Multicollinearity

  * The Dummy Variable Trap leads to the problem known as Multicollinearity. It occurs where there is a dependency between the independent features.

  * Multicollinearity is the occurrence of high intercorrelations among two or more independent variables

  * In general, multicollinearity can lead to wider confidence intervals that produce less reliable probabilities in terms of the effect of independent variables in a model.

  * So, in order to overcome the problem of multicollinearity, one of the dummy variables has to
be dropped.

3. Dummy Variable Trap

  * The Dummy Variable Trap leads to the problem known as Multicollinearity. Multicollinearity occurs where there is a dependency between the independent features.

  * The Dummy Variable trap is a scenario in which the independent variables are multicollinear - a scenario in which two or more variables are highly correlated.
  
  * In general, multicollinearity can lead to wider confidence intervals that produce less reliable probabilities in terms of the effect of independent variables in a model.

  * So, in order to overcome the problem of multicollinearity, one of the dummy variables has to
be dropped.""")
# Out:
# 1. One Hot Encoding
#
#   * It is one of the most popular and widely used algorithms to convert the categorical data into numerical data.
#
#   * OneHotEncoder(OHE) can be used for both nominal and ordinal data imported from sklearn.preprocessing.
#
#   * It can be easily performed using Label Encoder and One Hot Encoder imported from sklearn.preprocessing.
#
# 2. Multicollinearity
#
#   * The Dummy Variable Trap leads to the problem known as Multicollinearity. It occurs where there is a dependency between the independent features.
#
#   * Multicollinearity is the occurrence of high intercorrelations among two or more independent variables
#
#   * In general, multicollinearity can lead to wider confidence intervals that produce less reliable probabilities in terms of the effect of independent variables in a model.
#
#   * So, in order to overcome the problem of multicollinearity, one of the dummy variables has to
# be dropped.
#
# 3. Dummy Variable Trap
#
#   * The Dummy Variable Trap leads to the problem known as Multicollinearity. Multicollinearity occurs where there is a dependency between the independent features.
#
#   * The Dummy Variable trap is a scenario in which the independent variables are multicollinear - a scenario in which two or more variables are highly correlated.
#
#   * In general, multicollinearity can lead to wider confidence intervals that produce less reliable probabilities in terms of the effect of independent variables in a model.
#
#   * So, in order to overcome the problem of multicollinearity, one of the dummy variables has to
# be dropped.

# %%
#@title <b>What is Nominal and Ordinal Variables?</b>

print("""1. Nominal Data

  * Nominal data is a type of data where order of data doesn't matter i.e. we don't need to sort the data.

  * It can be encoded using get_dummies from pandas library.

  * Student Pass or Fail Classification can be a good example for Nominal Data.

2. Ordinal Data

  * Ordinal Data is a type of data in which order matters i.e. we need to sort the data before performing any operations on it.

  * It can be encoded using get_dummies from pandas library or Label Encoder and One Hot Encoder imported from sklearn.preprocessing.
  
  * Movie Ratings is a good example of Ordinal Data.
  
  """)
# Out:
# 1. Nominal Data
#
#   * Nominal data is a type of data where order of data doesn't matter i.e. we don't need to sort the data.
#
#   * It can be encoded using get_dummies from pandas library.
#
#   * Student Pass or Fail Classification can be a good example for Nominal Data.
#
# 2. Ordinal Data
#
#   * Ordinal Data is a type of data in which order matters i.e. we need to sort the data before performing any operations on it.
#
#   * It can be encoded using get_dummies from pandas library or Label Encoder and One Hot Encoder imported from sklearn.preprocessing.
#
#   * Movie Ratings is a good example of Ordinal Data.

# %% [markdown]
# <b>Salary Dataset of 52 professors having categorical columns. Apply dummy variables concept and one-hot-encoding on categorical columns.</b>  Dataset Link- <a href="https://data.princeton.edu/wws509/datasets/salary.dat">Click here</a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.compose import ColumnTransformer

# %%
df = pd.read_table("salary.dat.txt",delim_whitespace=True)
df
# Out:
#         sx         rk  yr         dg  yd     sl
# 0     male       full  25  doctorate  35  36350
# 1     male       full  13  doctorate  22  35350
# 2     male       full  10  doctorate  23  28200
# 3   female       full   7  doctorate  27  26775
# 4     male       full  19    masters  30  33696
# 5     male       full  16  doctorate  21  28516
# 6   female       full   0    masters  32  24900
# 7     male       full  16  doctorate  18  31909
# 8     male       full  13    masters  30  31850
# 9     male       full  13    masters  31  32850
# 10    male       full  12  doctorate  22  27025
# 11    male  associate  15  doctorate  19  24750
# 12    male       full   9  doctorate  17  28200
# 13    male  associate   9    masters  27  23712
# 14    male       full   9  doctorate  24  25748
# 15    male       full   7  doctorate  15  29342
# 16    male       full  13  doctorate  20  31114
# 17    male  associate  11    masters  14  24742
# 18    male  associate  10    masters  15  22906
# 19    male       full   6    masters  21  24450
# 20    male  assistant  16    masters  23  19175
# 21    male  associate   8    masters  31  20525
# 22    male       full   7  doctorate  13  27959
# 23  female       full   8  doctorate  24  38045
# 24    male  associate   9  doctorate  12  24832
# 25    male       full   5  doctorate  18  25400
# 26    male  associate  11  doctorate  14  24800
# 27  female       full   5  doctorate  16  25500
# 28    male  associate   3    masters   7  26182
# 29    male  associate   3    masters  17  23725
# 30  female  assistant  10    masters  15  21600
# 31    male  associate  11    masters  31  23300
# 32    male  assistant   9    masters  14  23713
# 33  female  associate   4    masters  33  20690
# 34  female  associate   6    masters  29  22450
# 35    male  associate   1  doctorate   9  20850
# 36  female  assistant   8  doctorate  14  18304
# 37    male  assistant   4  doctorate   4  17095
# 38    male  assistant   4  doctorate   5  16700
# 39    male  assistant   4  doctorate   4  17600
# 40    male  assistant   3  doctorate   4  18075
# 41    male  assistant   3    masters  11  18000
# 42    male  associate   0  doctorate   7  20999
# 43  female  assistant   3  doctorate   3  17250
# 44    male  assistant   2  doctorate   3  16500
# 45    male  assistant   2  doctorate   1  16094
# 46  female  assistant   2  doctorate   6  16150
# 47  female  assistant   2  doctorate   2  15350
# 48    male  assistant   1  doctorate   1  16244
# 49  female  assistant   1  doctorate   1  16686
# 50  female  assistant   1  doctorate   1  15000
# 51  female  assistant   0  doctorate   2  20300

# %%
df.head(10)
# Out:
#        sx    rk  yr         dg  yd     sl
# 0    male  full  25  doctorate  35  36350
# 1    male  full  13  doctorate  22  35350
# 2    male  full  10  doctorate  23  28200
# 3  female  full   7  doctorate  27  26775
# 4    male  full  19    masters  30  33696
# 5    male  full  16  doctorate  21  28516
# 6  female  full   0    masters  32  24900
# 7    male  full  16  doctorate  18  31909
# 8    male  full  13    masters  30  31850
# 9    male  full  13    masters  31  32850

# %%
df.tail(10)
# Out:
#         sx         rk  yr         dg  yd     sl
# 42    male  associate   0  doctorate   7  20999
# 43  female  assistant   3  doctorate   3  17250
# 44    male  assistant   2  doctorate   3  16500
# 45    male  assistant   2  doctorate   1  16094
# 46  female  assistant   2  doctorate   6  16150
# 47  female  assistant   2  doctorate   2  15350
# 48    male  assistant   1  doctorate   1  16244
# 49  female  assistant   1  doctorate   1  16686
# 50  female  assistant   1  doctorate   1  15000
# 51  female  assistant   0  doctorate   2  20300

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sx      52 non-null     object
#  1   rk      52 non-null     object
#  2   yr      52 non-null     int64
#  3   dg      52 non-null     object
#  4   yd      52 non-null     int64
#  5   sl      52 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 2.6+ KB

# %%
df.describe(include="all")
# Out:
#           sx    rk         yr         dg         yd            sl
# count     52    52  52.000000         52  52.000000     52.000000
# unique     2     3        NaN          2        NaN           NaN
# top     male  full        NaN  doctorate        NaN           NaN
# freq      38    20        NaN         34        NaN           NaN
# mean     NaN   NaN   7.480769        NaN  16.115385  23797.653846
# std      NaN   NaN   5.507536        NaN  10.222340   5917.289154
# min      NaN   NaN   0.000000        NaN   1.000000  15000.000000
# 25%      NaN   NaN   3.000000        NaN   6.750000  18246.750000
# 50%      NaN   NaN   7.000000        NaN  15.500000  23719.000000
# 75%      NaN   NaN  11.000000        NaN  23.250000  27258.500000
# max      NaN   NaN  25.000000        NaN  35.000000  38045.000000

# %%
df.kurt()
# Out:
# yr    0.609804
# yd   -1.123137
# sl   -0.433458
# dtype: float64

# %%
df.skew()
# Out:
# yr    0.791957
# yd    0.077261
# sl    0.474698
# dtype: float64

# %%
df.keys()
# Out:
# Index(['sx', 'rk', 'yr', 'dg', 'yd', 'sl'], dtype='object')

# %%
df.columns
# Out:
# Index(['sx', 'rk', 'yr', 'dg', 'yd', 'sl'], dtype='object')

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=52, step=1),
#  Index(['sx', 'rk', 'yr', 'dg', 'yd', 'sl'], dtype='object')]

# %%
df.boxplot(rot=45)
plt.show()

# %%
df.hist(figsize=(15,20),xrot=45,yrot=45)
plt.show()

# %%
df.dtypes
# Out:
# sx    object
# rk    object
# yr     int64
# dg    object
# yd     int64
# sl     int64
# dtype: object

# %%
df.duplicated().any()
# Out:
# False

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna()
# Out:
#        sx     rk     yr     dg     yd     sl
# 0   False  False  False  False  False  False
# 1   False  False  False  False  False  False
# 2   False  False  False  False  False  False
# 3   False  False  False  False  False  False
# 4   False  False  False  False  False  False
# 5   False  False  False  False  False  False
# 6   False  False  False  False  False  False
# 7   False  False  False  False  False  False
# 8   False  False  False  False  False  False
# 9   False  False  False  False  False  False
# 10  False  False  False  False  False  False
# 11  False  False  False  False  False  False
# 12  False  False  False  False  False  False
# 13  False  False  False  False  False  False
# 14  False  False  False  False  False  False
# 15  False  False  False  False  False  False
# 16  False  False  False  False  False  False
# 17  False  False  False  False  False  False
# 18  False  False  False  False  False  False
# 19  False  False  False  False  False  False
# 20  False  False  False  False  False  False
# 21  False  False  False  False  False  False
# 22  False  False  False  False  False  False
# 23  False  False  False  False  False  False
# 24  False  False  False  False  False  False
# 25  False  False  False  False  False  False
# 26  False  False  False  False  False  False
# 27  False  False  False  False  False  False
# 28  False  False  False  False  False  False
# 29  False  False  False  False  False  False
# 30  False  False  False  False  False  False
# 31  False  False  False  False  False  False
# 32  False  False  False  False  False  False
# 33  False  False  False  False  False  False
# 34  False  False  False  False  False  False
# 35  False  False  False  False  False  False
# 36  False  False  False  False  False  False
# 37  False  False  False  False  False  False
# 38  False  False  False  False  False  False
# 39  False  False  False  False  False  False
# 40  False  False  False  False  False  False
# 41  False  False  False  False  False  False
# 42  False  False  False  False  False  False
# 43  False  False  False  False  False  False
# 44  False  False  False  False  False  False
# 45  False  False  False  False  False  False
# 46  False  False  False  False  False  False
# 47  False  False  False  False  False  False
# 48  False  False  False  False  False  False
# 49  False  False  False  False  False  False
# 50  False  False  False  False  False  False
# 51  False  False  False  False  False  False

# %%
df.isnull().any()
# Out:
# sx    False
# rk    False
# yr    False
# dg    False
# yd    False
# sl    False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# sx    0
# rk    0
# yr    0
# dg    0
# yd    0
# sl    0
# dtype: int64

# %%
msno.bar(df.sample(51),color="cyan")
plt.show()

# %%
msno.matrix(df.sample(51),color=(1, 0, 1))
plt.show()

# %%
df.corr()
# Out:
#           yr        yd        sl
# yr  1.000000  0.638776  0.700669
# yd  0.638776  1.000000  0.674854
# sl  0.700669  0.674854  1.000000

# %%
fig = plt.figure(figsize = (12,10))
sns.heatmap(df.corr(), cmap='inferno', annot = True) 
plt.show()

# %%
corr = df.corr()
sns.heatmap((corr),
xticklabels=corr.columns.values,
yticklabels=corr.columns.values,cmap='cubehelix_r',annot=False,fmt=".2g")
plt.title('Heatmap of Correlation Matrix', fontsize=20)
corr
# Out:
#           yr        yd        sl
# yr  1.000000  0.638776  0.700669
# yd  0.638776  1.000000  0.674854
# sl  0.700669  0.674854  1.000000

# %%
plt.figure(figsize=(14,14))
sns.heatmap(df.cov(), annot=True, fmt =".2f",square=True,cmap='rainbow')
plt.title("Covariation",fontsize = 15)
plt.show()

# %%
df1 = pd.get_dummies(df,columns = ['sx','rk','dg'])
df1.head(10)
# Out:
#    yr  yd     sl  sx_female  ...  rk_associate  rk_full  dg_doctorate  dg_masters
# 0  25  35  36350          0  ...             0        1             1           0
# 1  13  22  35350          0  ...             0        1             1           0
# 2  10  23  28200          0  ...             0        1             1           0
# 3   7  27  26775          1  ...             0        1             1           0
# 4  19  30  33696          0  ...             0        1             0           1
# 5  16  21  28516          0  ...             0        1             1           0
# 6   0  32  24900          1  ...             0        1             0           1
# 7  16  18  31909          0  ...             0        1             1           0
# 8  13  30  31850          0  ...             0        1             0           1
# 9  13  31  32850          0  ...             0        1             0           1
#
# [10 rows x 10 columns]

# %%
df1.tail(10)
# Out:
#     yr  yd     sl  sx_female  ...  rk_associate  rk_full  dg_doctorate  dg_masters
# 42   0   7  20999          0  ...             1        0             1           0
# 43   3   3  17250          1  ...             0        0             1           0
# 44   2   3  16500          0  ...             0        0             1           0
# 45   2   1  16094          0  ...             0        0             1           0
# 46   2   6  16150          1  ...             0        0             1           0
# 47   2   2  15350          1  ...             0        0             1           0
# 48   1   1  16244          0  ...             0        0             1           0
# 49   1   1  16686          1  ...             0        0             1           0
# 50   1   1  15000          1  ...             0        0             1           0
# 51   0   2  20300          1  ...             0        0             1           0
#
# [10 rows x 10 columns]

# %%
df1=df1.drop(['sx_female','rk_associate','dg_masters'], axis=1)
df1.head(10)
# Out:
#    yr  yd     sl  sx_male  rk_assistant  rk_full  dg_doctorate
# 0  25  35  36350        1             0        1             1
# 1  13  22  35350        1             0        1             1
# 2  10  23  28200        1             0        1             1
# 3   7  27  26775        0             0        1             1
# 4  19  30  33696        1             0        1             0
# 5  16  21  28516        1             0        1             1
# 6   0  32  24900        0             0        1             0
# 7  16  18  31909        1             0        1             1
# 8  13  30  31850        1             0        1             0
# 9  13  31  32850        1             0        1             0

# %%
df1.tail(10)
# Out:
#     yr  yd     sl  sx_male  rk_assistant  rk_full  dg_doctorate
# 42   0   7  20999        1             0        0             1
# 43   3   3  17250        0             1        0             1
# 44   2   3  16500        1             1        0             1
# 45   2   1  16094        1             1        0             1
# 46   2   6  16150        0             1        0             1
# 47   2   2  15350        0             1        0             1
# 48   1   1  16244        1             1        0             1
# 49   1   1  16686        0             1        0             1
# 50   1   1  15000        0             1        0             1
# 51   0   2  20300        0             1        0             1

# %%
le = LabelEncoder()

# %%
df2 = df1

df2.sx_male=le.fit_transform(df2.sx_male)
df2.sx_male.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    0
# 4    1
# Name: sx_male, dtype: int64

# %%
df2 = df1

df2.rk_assistant=le.fit_transform(df2.rk_assistant)
df2.rk_assistant.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: rk_assistant, dtype: int64

# %%
df2 = df1

df2.dg_doctorate=le.fit_transform(df2.dg_doctorate)
df2.dg_doctorate.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    0
# Name: dg_doctorate, dtype: int64

# %%
t = [('sx',OneHotEncoder(),[3]),('rk',OneHotEncoder(),[4]),('dg',OneHotEncoder(),[6])]

ct = ColumnTransformer(transformers=t,remainder="passthrough")
ct
# Out:
# ColumnTransformer(n_jobs=None, remainder='passthrough', sparse_threshold=0.3,
#                   transformer_weights=None,
#                   transformers=[('sx',
#                                  OneHotEncoder(categories='auto', drop=None,
#                                                dtype=<class 'numpy.float64'>,
#                                                handle_unknown='error',
#                                                sparse=True),
#                                  [3]),
#                                 ('rk',
#                                  OneHotEncoder(categories='auto', drop=None,
#                                                dtype=<class 'numpy.float64'>,
#                                                handle_unknown='error',
#                                                sparse=True),
#                                  [4]),
#                                 ('dg',
#                                  OneHotEncoder(categories='auto', drop=None,
#                                                dtype=<class 'numpy.float64'>,
#                                                handle_unknown='error',
#                                                sparse=True),
#                                  [6])],
#                   verbose=False)

# %%
newct=ct.fit_transform(df1) 
newct
# Out:
# array([[0.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00,
#         1.0000e+00, 2.5000e+01, 3.5000e+01, 3.6350e+04, 1.0000e+00],
#        [0.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00,
#         1.0000e+00, 1.3000e+01, 2.2000e+01, 3.5350e+04, 1.0000e+00],
#        [0.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00,
#         1.0000e+00, 1.0000e+01, 2.3000e+01, 2.8200e+04, 1.0000e+00],
#        [1.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00,
#         1.0000e+00, 7.0000e+00, 2.7000e+01, 2.6775e+04, 1.0000e+00],
#        [0.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00,
#         0.0000e+00, 1.9000e+01, 3.0000e+01, 3.3696e+04, 1.0000e+00],
#        [0.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00,
#         1.0000e+00, 1.6000e+01, 2.1000e+01, 2.8516e+04, 1.0000e+00],
#        [1.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00,
#         0.0000e+00, 0.0000e+00, 3.2000e+01, 2.4900e+04, 1.0000e+00],
#        [0.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00,
#         1.0000e+00, 1.6000e+01, 1.8000e+01, 3.1909e+04, 1.0000e+00],
#        [0.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00,
#         0.0000e+00, 1.3000e+01, 3.0000e+01, 3.1850e+04, 1.0000e+00],
#        [0.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00,
#         0.0000e+00, 1.3000e+01, 3.1000e+01, 3.2850e+04, 1.0000e+00],
#        [0.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00,
#         1.0000e+00, 1.2000e+01, 2.2000e+01, 2.7025e+04, 1.0000e+00],
#        [0.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00,
#         1.0000e+00, 1.5000e+01, 1.9000e+01, 2.4750e+04, 0.0000e+00],
#        [0.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00,
#         1.0000e+00, 9.0000e+00, 1.7000e+01, 2.8200e+04, 1.0000e+00],
#        [0.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00,
#         0.0000e+00, 9.0000e+00, 2.7000e+01, 2.3712e+04, 0.0000e+00],
#        [0.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00,
#         1.0000e+00, 9.0000e+00, 2.4000e+01, 2.5748e+04, 1.0000e+00],
#        [0.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00,
#         1.0000e+00, 7.0000e+00, 1.5000e+01, 2.9342e+04, 1.0000e+00],
#        [0.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00,
#         1.0000e+00, 1.3000e+01, 2.0000e+01, 3.1114e+04, 1.0000e+00],
#        [0.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00,
#         0.0000e+00, 1.1000e+01, 1.4000e+01, 2.4742e+04, 0.0000e+00],
#        [0.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00,
#         0.0000e+00, 1.0000e+01, 1.5000e+01, 2.2906e+04, 0.0000e+00],
#        [0.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00,
#         0.0000e+00, 6.0000e+00, 2.1000e+01, 2.4450e+04, 1.0000e+00],
#        [0.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00, 1.0000e+00,
#         0.0000e+00, 1.6000e+01, 2.3000e+01, 1.9175e+04, 0.0000e+00],
#        [0.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00,
#         0.0000e+00, 8.0000e+00, 3.1000e+01, 2.0525e+04, 0.0000e+00],
#        [0.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00,
#         1.0000e+00, 7.0000e+00, 1.3000e+01, 2.7959e+04, 1.0000e+00],
#        [1.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00,
#         1.0000e+00, 8.0000e+00, 2.4000e+01, 3.8045e+04, 1.0000e+00],
#        [0.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00,
#         1.0000e+00, 9.0000e+00, 1.2000e+01, 2.4832e+04, 0.0000e+00],
#        [0.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00,
#         1.0000e+00, 5.0000e+00, 1.8000e+01, 2.5400e+04, 1.0000e+00],
#        [0.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00,
#         1.0000e+00, 1.1000e+01, 1.4000e+01, 2.4800e+04, 0.0000e+00],
#        [1.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00,
#         1.0000e+00, 5.0000e+00, 1.6000e+01, 2.5500e+04, 1.0000e+00],
#        [0.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00,
#         0.0000e+00, 3.0000e+00, 7.0000e+00, 2.6182e+04, 0.0000e+00],
#        [0.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00,
#         0.0000e+00, 3.0000e+00, 1.7000e+01, 2.3725e+04, 0.0000e+00],
#        [1.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 1.0000e+00,
#         0.0000e+00, 1.0000e+01, 1.5000e+01, 2.1600e+04, 0.0000e+00],
#        [0.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00,
#         0.0000e+00, 1.1000e+01, 3.1000e+01, 2.3300e+04, 0.0000e+00],
#        [0.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00, 1.0000e+00,
#         0.0000e+00, 9.0000e+00, 1.4000e+01, 2.3713e+04, 0.0000e+00],
#        [1.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00,
#         0.0000e+00, 4.0000e+00, 3.3000e+01, 2.0690e+04, 0.0000e+00],
#        [1.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00,
#         0.0000e+00, 6.0000e+00, 2.9000e+01, 2.2450e+04, 0.0000e+00],
#        [0.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00,
#         1.0000e+00, 1.0000e+00, 9.0000e+00, 2.0850e+04, 0.0000e+00],
#        [1.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
#         1.0000e+00, 8.0000e+00, 1.4000e+01, 1.8304e+04, 0.0000e+00],
#        [0.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
#         1.0000e+00, 4.0000e+00, 4.0000e+00, 1.7095e+04, 0.0000e+00],
#        [0.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
#         1.0000e+00, 4.0000e+00, 5.0000e+00, 1.6700e+04, 0.0000e+00],
#        [0.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
#         1.0000e+00, 4.0000e+00, 4.0000e+00, 1.7600e+04, 0.0000e+00],
#        [0.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
#         1.0000e+00, 3.0000e+00, 4.0000e+00, 1.8075e+04, 0.0000e+00],
#        [0.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00, 1.0000e+00,
#         0.0000e+00, 3.0000e+00, 1.1000e+01, 1.8000e+04, 0.0000e+00],
#        [0.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00,
#         1.0000e+00, 0.0000e+00, 7.0000e+00, 2.0999e+04, 0.0000e+00],
#        [1.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
#         1.0000e+00, 3.0000e+00, 3.0000e+00, 1.7250e+04, 0.0000e+00],
#        [0.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
#         1.0000e+00, 2.0000e+00, 3.0000e+00, 1.6500e+04, 0.0000e+00],
#        [0.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
#         1.0000e+00, 2.0000e+00, 1.0000e+00, 1.6094e+04, 0.0000e+00],
#        [1.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
#         1.0000e+00, 2.0000e+00, 6.0000e+00, 1.6150e+04, 0.0000e+00],
#        [1.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
#         1.0000e+00, 2.0000e+00, 2.0000e+00, 1.5350e+04, 0.0000e+00],
#        [0.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
#         1.0000e+00, 1.0000e+00, 1.0000e+00, 1.6244e+04, 0.0000e+00],
#        [1.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
#         1.0000e+00, 1.0000e+00, 1.0000e+00, 1.6686e+04, 0.0000e+00],
#        [1.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
#         1.0000e+00, 1.0000e+00, 1.0000e+00, 1.5000e+04, 0.0000e+00],
#        [1.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
#         1.0000e+00, 0.0000e+00, 2.0000e+00, 2.0300e+04, 0.0000e+00]])

# %%
ct=ColumnTransformer([('sx',OneHotEncoder(),[0])],remainder="passthrough")
newct=ct.fit_transform(df) 
newct
# Out:
# array([[0.0, 1.0, 'full', 25, 'doctorate', 35, 36350],
#        [0.0, 1.0, 'full', 13, 'doctorate', 22, 35350],
#        [0.0, 1.0, 'full', 10, 'doctorate', 23, 28200],
#        [1.0, 0.0, 'full', 7, 'doctorate', 27, 26775],
#        [0.0, 1.0, 'full', 19, 'masters', 30, 33696],
#        [0.0, 1.0, 'full', 16, 'doctorate', 21, 28516],
#        [1.0, 0.0, 'full', 0, 'masters', 32, 24900],
#        [0.0, 1.0, 'full', 16, 'doctorate', 18, 31909],
#        [0.0, 1.0, 'full', 13, 'masters', 30, 31850],
#        [0.0, 1.0, 'full', 13, 'masters', 31, 32850],
#        [0.0, 1.0, 'full', 12, 'doctorate', 22, 27025],
#        [0.0, 1.0, 'associate', 15, 'doctorate', 19, 24750],
#        [0.0, 1.0, 'full', 9, 'doctorate', 17, 28200],
#        [0.0, 1.0, 'associate', 9, 'masters', 27, 23712],
#        [0.0, 1.0, 'full', 9, 'doctorate', 24, 25748],
#        [0.0, 1.0, 'full', 7, 'doctorate', 15, 29342],
#        [0.0, 1.0, 'full', 13, 'doctorate', 20, 31114],
#        [0.0, 1.0, 'associate', 11, 'masters', 14, 24742],
#        [0.0, 1.0, 'associate', 10, 'masters', 15, 22906],
#        [0.0, 1.0, 'full', 6, 'masters', 21, 24450],
#        [0.0, 1.0, 'assistant', 16, 'masters', 23, 19175],
#        [0.0, 1.0, 'associate', 8, 'masters', 31, 20525],
#        [0.0, 1.0, 'full', 7, 'doctorate', 13, 27959],
#        [1.0, 0.0, 'full', 8, 'doctorate', 24, 38045],
#        [0.0, 1.0, 'associate', 9, 'doctorate', 12, 24832],
#        [0.0, 1.0, 'full', 5, 'doctorate', 18, 25400],
#        [0.0, 1.0, 'associate', 11, 'doctorate', 14, 24800],
#        [1.0, 0.0, 'full', 5, 'doctorate', 16, 25500],
#        [0.0, 1.0, 'associate', 3, 'masters', 7, 26182],
#        [0.0, 1.0, 'associate', 3, 'masters', 17, 23725],
#        [1.0, 0.0, 'assistant', 10, 'masters', 15, 21600],
#        [0.0, 1.0, 'associate', 11, 'masters', 31, 23300],
#        [0.0, 1.0, 'assistant', 9, 'masters', 14, 23713],
#        [1.0, 0.0, 'associate', 4, 'masters', 33, 20690],
#        [1.0, 0.0, 'associate', 6, 'masters', 29, 22450],
#        [0.0, 1.0, 'associate', 1, 'doctorate', 9, 20850],
#        [1.0, 0.0, 'assistant', 8, 'doctorate', 14, 18304],
#        [0.0, 1.0, 'assistant', 4, 'doctorate', 4, 17095],
#        [0.0, 1.0, 'assistant', 4, 'doctorate', 5, 16700],
#        [0.0, 1.0, 'assistant', 4, 'doctorate', 4, 17600],
#        [0.0, 1.0, 'assistant', 3, 'doctorate', 4, 18075],
#        [0.0, 1.0, 'assistant', 3, 'masters', 11, 18000],
#        [0.0, 1.0, 'associate', 0, 'doctorate', 7, 20999],
#        [1.0, 0.0, 'assistant', 3, 'doctorate', 3, 17250],
#        [0.0, 1.0, 'assistant', 2, 'doctorate', 3, 16500],
#        [0.0, 1.0, 'assistant', 2, 'doctorate', 1, 16094],
#        [1.0, 0.0, 'assistant', 2, 'doctorate', 6, 16150],
#        [1.0, 0.0, 'assistant', 2, 'doctorate', 2, 15350],
#        [0.0, 1.0, 'assistant', 1, 'doctorate', 1, 16244],
#        [1.0, 0.0, 'assistant', 1, 'doctorate', 1, 16686],
#        [1.0, 0.0, 'assistant', 1, 'doctorate', 1, 15000],
#        [1.0, 0.0, 'assistant', 0, 'doctorate', 2, 20300]], dtype=object)

# %%
ct=ColumnTransformer([('rk',OneHotEncoder(),[1])],remainder="passthrough")
newct=ct.fit_transform(df) 
newct
# Out:
# array([[0.0, 0.0, 1.0, 'male', 25, 'doctorate', 35, 36350],
#        [0.0, 0.0, 1.0, 'male', 13, 'doctorate', 22, 35350],
#        [0.0, 0.0, 1.0, 'male', 10, 'doctorate', 23, 28200],
#        [0.0, 0.0, 1.0, 'female', 7, 'doctorate', 27, 26775],
#        [0.0, 0.0, 1.0, 'male', 19, 'masters', 30, 33696],
#        [0.0, 0.0, 1.0, 'male', 16, 'doctorate', 21, 28516],
#        [0.0, 0.0, 1.0, 'female', 0, 'masters', 32, 24900],
#        [0.0, 0.0, 1.0, 'male', 16, 'doctorate', 18, 31909],
#        [0.0, 0.0, 1.0, 'male', 13, 'masters', 30, 31850],
#        [0.0, 0.0, 1.0, 'male', 13, 'masters', 31, 32850],
#        [0.0, 0.0, 1.0, 'male', 12, 'doctorate', 22, 27025],
#        [0.0, 1.0, 0.0, 'male', 15, 'doctorate', 19, 24750],
#        [0.0, 0.0, 1.0, 'male', 9, 'doctorate', 17, 28200],
#        [0.0, 1.0, 0.0, 'male', 9, 'masters', 27, 23712],
#        [0.0, 0.0, 1.0, 'male', 9, 'doctorate', 24, 25748],
#        [0.0, 0.0, 1.0, 'male', 7, 'doctorate', 15, 29342],
#        [0.0, 0.0, 1.0, 'male', 13, 'doctorate', 20, 31114],
#        [0.0, 1.0, 0.0, 'male', 11, 'masters', 14, 24742],
#        [0.0, 1.0, 0.0, 'male', 10, 'masters', 15, 22906],
#        [0.0, 0.0, 1.0, 'male', 6, 'masters', 21, 24450],
#        [1.0, 0.0, 0.0, 'male', 16, 'masters', 23, 19175],
#        [0.0, 1.0, 0.0, 'male', 8, 'masters', 31, 20525],
#        [0.0, 0.0, 1.0, 'male', 7, 'doctorate', 13, 27959],
#        [0.0, 0.0, 1.0, 'female', 8, 'doctorate', 24, 38045],
#        [0.0, 1.0, 0.0, 'male', 9, 'doctorate', 12, 24832],
#        [0.0, 0.0, 1.0, 'male', 5, 'doctorate', 18, 25400],
#        [0.0, 1.0, 0.0, 'male', 11, 'doctorate', 14, 24800],
#        [0.0, 0.0, 1.0, 'female', 5, 'doctorate', 16, 25500],
#        [0.0, 1.0, 0.0, 'male', 3, 'masters', 7, 26182],
#        [0.0, 1.0, 0.0, 'male', 3, 'masters', 17, 23725],
#        [1.0, 0.0, 0.0, 'female', 10, 'masters', 15, 21600],
#        [0.0, 1.0, 0.0, 'male', 11, 'masters', 31, 23300],
#        [1.0, 0.0, 0.0, 'male', 9, 'masters', 14, 23713],
#        [0.0, 1.0, 0.0, 'female', 4, 'masters', 33, 20690],
#        [0.0, 1.0, 0.0, 'female', 6, 'masters', 29, 22450],
#        [0.0, 1.0, 0.0, 'male', 1, 'doctorate', 9, 20850],
#        [1.0, 0.0, 0.0, 'female', 8, 'doctorate', 14, 18304],
#        [1.0, 0.0, 0.0, 'male', 4, 'doctorate', 4, 17095],
#        [1.0, 0.0, 0.0, 'male', 4, 'doctorate', 5, 16700],
#        [1.0, 0.0, 0.0, 'male', 4, 'doctorate', 4, 17600],
#        [1.0, 0.0, 0.0, 'male', 3, 'doctorate', 4, 18075],
#        [1.0, 0.0, 0.0, 'male', 3, 'masters', 11, 18000],
#        [0.0, 1.0, 0.0, 'male', 0, 'doctorate', 7, 20999],
#        [1.0, 0.0, 0.0, 'female', 3, 'doctorate', 3, 17250],
#        [1.0, 0.0, 0.0, 'male', 2, 'doctorate', 3, 16500],
#        [1.0, 0.0, 0.0, 'male', 2, 'doctorate', 1, 16094],
#        [1.0, 0.0, 0.0, 'female', 2, 'doctorate', 6, 16150],
#        [1.0, 0.0, 0.0, 'female', 2, 'doctorate', 2, 15350],
#        [1.0, 0.0, 0.0, 'male', 1, 'doctorate', 1, 16244],
#        [1.0, 0.0, 0.0, 'female', 1, 'doctorate', 1, 16686],
#        [1.0, 0.0, 0.0, 'female', 1, 'doctorate', 1, 15000],
#        [1.0, 0.0, 0.0, 'female', 0, 'doctorate', 2, 20300]], dtype=object)

# %%
ct=ColumnTransformer([('dg',OneHotEncoder(),[3])],remainder="passthrough")
newct=ct.fit_transform(df) 
newct
# Out:
# array([[1.0, 0.0, 'male', 'full', 25, 35, 36350],
#        [1.0, 0.0, 'male', 'full', 13, 22, 35350],
#        [1.0, 0.0, 'male', 'full', 10, 23, 28200],
#        [1.0, 0.0, 'female', 'full', 7, 27, 26775],
#        [0.0, 1.0, 'male', 'full', 19, 30, 33696],
#        [1.0, 0.0, 'male', 'full', 16, 21, 28516],
#        [0.0, 1.0, 'female', 'full', 0, 32, 24900],
#        [1.0, 0.0, 'male', 'full', 16, 18, 31909],
#        [0.0, 1.0, 'male', 'full', 13, 30, 31850],
#        [0.0, 1.0, 'male', 'full', 13, 31, 32850],
#        [1.0, 0.0, 'male', 'full', 12, 22, 27025],
#        [1.0, 0.0, 'male', 'associate', 15, 19, 24750],
#        [1.0, 0.0, 'male', 'full', 9, 17, 28200],
#        [0.0, 1.0, 'male', 'associate', 9, 27, 23712],
#        [1.0, 0.0, 'male', 'full', 9, 24, 25748],
#        [1.0, 0.0, 'male', 'full', 7, 15, 29342],
#        [1.0, 0.0, 'male', 'full', 13, 20, 31114],
#        [0.0, 1.0, 'male', 'associate', 11, 14, 24742],
#        [0.0, 1.0, 'male', 'associate', 10, 15, 22906],
#        [0.0, 1.0, 'male', 'full', 6, 21, 24450],
#        [0.0, 1.0, 'male', 'assistant', 16, 23, 19175],
#        [0.0, 1.0, 'male', 'associate', 8, 31, 20525],
#        [1.0, 0.0, 'male', 'full', 7, 13, 27959],
#        [1.0, 0.0, 'female', 'full', 8, 24, 38045],
#        [1.0, 0.0, 'male', 'associate', 9, 12, 24832],
#        [1.0, 0.0, 'male', 'full', 5, 18, 25400],
#        [1.0, 0.0, 'male', 'associate', 11, 14, 24800],
#        [1.0, 0.0, 'female', 'full', 5, 16, 25500],
#        [0.0, 1.0, 'male', 'associate', 3, 7, 26182],
#        [0.0, 1.0, 'male', 'associate', 3, 17, 23725],
#        [0.0, 1.0, 'female', 'assistant', 10, 15, 21600],
#        [0.0, 1.0, 'male', 'associate', 11, 31, 23300],
#        [0.0, 1.0, 'male', 'assistant', 9, 14, 23713],
#        [0.0, 1.0, 'female', 'associate', 4, 33, 20690],
#        [0.0, 1.0, 'female', 'associate', 6, 29, 22450],
#        [1.0, 0.0, 'male', 'associate', 1, 9, 20850],
#        [1.0, 0.0, 'female', 'assistant', 8, 14, 18304],
#        [1.0, 0.0, 'male', 'assistant', 4, 4, 17095],
#        [1.0, 0.0, 'male', 'assistant', 4, 5, 16700],
#        [1.0, 0.0, 'male', 'assistant', 4, 4, 17600],
#        [1.0, 0.0, 'male', 'assistant', 3, 4, 18075],
#        [0.0, 1.0, 'male', 'assistant', 3, 11, 18000],
#        [1.0, 0.0, 'male', 'associate', 0, 7, 20999],
#        [1.0, 0.0, 'female', 'assistant', 3, 3, 17250],
#        [1.0, 0.0, 'male', 'assistant', 2, 3, 16500],
#        [1.0, 0.0, 'male', 'assistant', 2, 1, 16094],
#        [1.0, 0.0, 'female', 'assistant', 2, 6, 16150],
#        [1.0, 0.0, 'female', 'assistant', 2, 2, 15350],
#        [1.0, 0.0, 'male', 'assistant', 1, 1, 16244],
#        [1.0, 0.0, 'female', 'assistant', 1, 1, 16686],
#        [1.0, 0.0, 'female', 'assistant', 1, 1, 15000],
#        [1.0, 0.0, 'female', 'assistant', 0, 2, 20300]], dtype=object)
